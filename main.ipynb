# %%
import pandas as pd

# %%
data=pd.read_csv('gesture.csv')

# %%
data
# Out:
#       0.688117743  0.593009293     -4.06E-07  0.691041946  0.440940022  \
# 0        0.668216     0.591544 -1.100000e-06     0.666437     0.446299
# 1        0.653498     0.585667 -9.860000e-07     0.658857     0.437384
# 2        0.583263     0.595518 -1.030000e-06     0.582272     0.440167
# 3        0.513647     0.591081 -8.690000e-07     0.540781     0.456069
# 4        0.479073     0.607092 -7.100000e-07     0.516735     0.464845
# ...           ...          ...           ...          ...          ...
# 1066     0.636701     0.365888 -5.750000e-07     0.682391     0.486272
# 1067     0.628024     0.364727 -5.970000e-07     0.675975     0.482619
# 1068     0.633447     0.365304 -6.010000e-07     0.679064     0.481344
# 1069     0.620633     0.388220 -6.190000e-07     0.674053     0.505894
# 1070     0.584240     0.595816  1.560000e-09     0.666308     0.656054
#
#       -0.025056157  0.752455592  0.314483821  -0.040358692  0.817279279  ...  \
# 0        -0.028154     0.719784     0.321250     -0.049640     0.774304  ...
# 1        -0.017697     0.717374     0.311174     -0.034439     0.776522  ...
# 2        -0.009760     0.640311     0.310167     -0.017871     0.704935  ...
# 3        -0.008800     0.600260     0.327611     -0.020741     0.658404  ...
# 4         0.006821     0.580948     0.335612     -0.000888     0.637491  ...
# ...            ...          ...          ...           ...          ...  ...
# 1066     -0.027574     0.760266     0.578968     -0.041539     0.830960  ...
# 1067     -0.028181     0.752079     0.576506     -0.042816     0.822351  ...
# 1068     -0.025569     0.754045     0.575437     -0.039408     0.823741  ...
# 1069     -0.026962     0.752892     0.589982     -0.039623     0.827283  ...
# 1070     -0.036317     0.758944     0.677199     -0.060030     0.825812  ...
#
#       0.92845732  0.567434728  -0.03541474  0.896890283  0.582251966  \
# 0       0.829782     0.617568    -0.080357     0.774890     0.631649
# 1       0.868612     0.601278    -0.058110     0.821572     0.611503
# 2       0.858261     0.596964    -0.018448     0.821823     0.612270
# 3       0.798588     0.644177    -0.040597     0.766758     0.659170
# 4       0.768447     0.648687    -0.026883     0.737894     0.666149
# ...          ...          ...          ...          ...          ...
# 1066    0.884736     0.197936    -0.071416     0.817087     0.235580
# 1067    0.870759     0.196213    -0.072431     0.805332     0.236165
# 1068    0.873506     0.196565    -0.072879     0.805839     0.235671
# 1069    0.843665     0.222208    -0.061264     0.785814     0.257463
# 1070    0.737727     0.357561    -0.096069     0.704620     0.417656
#
#       -0.031455927  0.873917639  0.592053652  -0.026976617   gesture1
# 0        -0.076487     0.742550     0.636567     -0.069559   gesture1
# 1        -0.050304     0.790660     0.611327     -0.043381   gesture1
# 2        -0.008991     0.787898     0.612118     -0.002582   gesture1
# 3        -0.028195     0.730575     0.649845     -0.019095   gesture1
# 4        -0.012917     0.704982     0.657455     -0.004796   gesture1
# ...            ...          ...          ...           ...        ...
# 1066     -0.056244     0.769040     0.262452     -0.031339   gesture2
# 1067     -0.056753     0.762546     0.263148     -0.032315   gesture2
# 1068     -0.056320     0.761513     0.264095     -0.031511   gesture2
# 1069     -0.049386     0.742690     0.286320     -0.028471   gesture2
# 1070     -0.078606     0.688121     0.443012     -0.058935   gesture2
#
# [1071 rows x 64 columns]

# %%
X=data.iloc[:,:-1].values
Y=data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier
cls=KNeighborsClassifier(n_neighbors=4)
cls.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_test1=cls.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test1,y_test))
# Out:
# 1.0

# %%
import pickle
model=open('model.pkl','wb')
pickle.dump(cls,model)
model.close()
